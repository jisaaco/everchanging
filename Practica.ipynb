# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
rosa = pd.read_csv('/mnt/72D08F32D08EFB9B/Users/Administrador/evechan/everchanging/rosa.csv',
                   encoding = 'utf-8')

# %%
probable = rosa['DIAGNOSTICO PROBABLE']
final = rosa['DIAGNOSTICO FINAL']
estatus = rosa['ESTATUS']
casuistica = pd.crosstab(estatus, probable)
sns.heatmap(data = casuistica,
            annot = True)
# Out:
# <Axes: xlabel='DIAGNOSTICO PROBABLE', ylabel='ESTATUS'>

# %%
sns.histplot(data = rosa,
             x = 'DIAGNOSTICO PROBABLE',
             hue = 'ESTATUS',
             multiple = 'stack').\
                  set(xlabel = 'DIAGNOSTICO PROBABLE',
                      ylabel = 'FRECUENCIA',
                      title = 'DISTRIBUCIÓN POR DIAGNÓSTICO PROBABLE Y ESTATUS')
# Out:
# [Text(0.5, 0, 'DIAGNOSTICO PROBABLE'),
#  Text(0, 0.5, 'FRECUENCIA'),
#  Text(0.5, 1.0, 'DISTRIBUCIÓN POR DIAGNÓSTICO PROBABLE Y ESTATUS')]

# %%
#mask = rosa[rosa['ESTATUS'] == 'CONFIRMADO']
sns.histplot(data = rosa,
             x = 'DIAGNOSTICO PROBABLE',
             hue = 'DIAGNOSTICO FINAL',
             multiple = 'stack').\
                  set(xlabel = 'DIAGNOSTICO PROBABLE',
                      ylabel = 'FRECUENCIA',
                      title = 'DISTRIBUCIÓN POR DIAGNÓSTICO PROBABLE Y FINAL')
# Out:
# [Text(0.5, 0, 'DIAGNOSTICO PROBABLE'),
#  Text(0, 0.5, 'FRECUENCIA'),
#  Text(0.5, 1.0, 'DISTRIBUCIÓN POR DIAGNÓSTICO PROBABLE Y FINAL')]

# %%
sns.displot(data = rosa,
            x = 'EDAD',
            hue = 'SEXO',
            multiple = 'stack').\
                  set(xlabel = 'EDAD',
                      ylabel = 'FRECUENCIA',
                      title = 'DISTRIBUCIÓN POR EDAD Y SEXO')
# Out:
# /mnt/72D08F32D08EFB9B/Users/Administrador/evechan/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = rosa,
            x = 'EDAD',
            hue = 'ESTATUS',
            multiple = 'stack').\
                  set(xlabel = 'EDAD',
                      ylabel = 'FRECUENCIA',
                      title = 'DISTRIBUCIÓN POR EDAD Y ESTATUS')
# Out:
# /mnt/72D08F32D08EFB9B/Users/Administrador/evechan/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = rosa,
            y = 'MUNICIPIO',
            hue = 'SEXO',
            multiple = 'stack').\
                  set(xlabel = 'FRECUENCIA',
                      ylabel = 'MUNICIPIO',
                      title = 'DISTRIBUCIÓN POR MUNICIPIO Y SEXO')
# Out:
# /mnt/72D08F32D08EFB9B/Users/Administrador/evechan/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = rosa,
            y = 'MUNICIPIO',
            hue = 'ESTATUS',
            multiple = 'stack').\
                  set(xlabel = 'FRECUENCIA',
                      ylabel = 'MUNICIPIO',
                      title = 'DISTRIBUCIÓN POR MUNICIPIO Y ESTATUS')
# Out:
# /mnt/72D08F32D08EFB9B/Users/Administrador/evechan/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = rosa,
            x = 'SEXO',
            hue = 'ESTATUS',
            multiple = 'stack').\
                  set(xlabel = 'SEXO',
                      ylabel = 'FRECUENCIA',
                      title = 'DISTRIBUCIÓN POR SEXO Y ESTATUS')
# Out:
# /mnt/72D08F32D08EFB9B/Users/Administrador/evechan/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data = rosa,
            y = 'SEMANA SUIVE',
            hue = 'ESTATUS',
            multiple = 'stack').\
                  set(xlabel = 'FRECUENCIA',
                      ylabel = 'SEMANA SUIVE',
                      title = 'DISTRIBUCIÓN POR SEMANA SUIVE Y ESTATUS')
# Out:
# /mnt/72D08F32D08EFB9B/Users/Administrador/evechan/.venv/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
